# %% [markdown]
# # Codes to pool data of all languages

# %% [markdown]
# 1. [Import packages](#Import-packages)
# 2. [Pre-preprocessing](#Pre-preprocessing)
# 3. [Pooling](#Pooling)
# 4. [Some simple analysis](#Some-simple-analysis)
# 5. [Preprocess data](#Preprocess-data)

# %% [markdown]
# ## Import packages

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pre-preprocessing

# %%
# load the original data
survey = pd.read_csv('ECP Survey.csv')
survey.head()
# Out:
#                      Timestamp  \
# 0  2020/05/03 6:49:52 am GMT+8
# 1  2020/05/03 6:53:20 am GMT+8
# 2  2020/05/03 7:42:07 am GMT+8
# 3  2020/05/03 7:47:39 am GMT+8
# 4  2020/05/03 7:51:14 am GMT+8
#
#   What gender do you identify with? A quel genre vous identifiez-vous? 您的性別？Cinsiyetiniz?  \
# 0                           Male / Homme / 男 / Erkek
# 1                           Male / Homme / 男 / Erkek
# 2                         Female / Femme / 女 / Kadın
# 3                           Male / Homme / 男 / Erkek
# 4                         Female / Femme / 女 / Kadın
#
#    How old are you? Quel âge avez-vous? 您的年齡？Yaşınız?  \
# 0                                                 23
# 1                                                 22
# 2                                                 23
# 3                                                 63
# 4                                                 57
#
# ...

# %%
print(f'Number of responses: {survey.shape[0]}')
# Out:
# Number of responses: 935

# %%
# rename the column names of basic information
survey.rename(columns={
    'Timestamp': 'timestamp',
    'What gender do you identify with? A quel genre vous identifiez-vous? 您的性別？Cinsiyetiniz?': 'gender',
    'How old are you? Quel âge avez-vous? 您的年齡？Yaşınız?': 'age',
    'Which language do you prefer to use to answer this survey? Quelle langue préférez-vous utiliser pour répondre à ce questionnaire? 您希望使用哪種語言來回答此調查？Bu anketi cevaplamak için hangi dili kullanmayı tercih edersiniz?': 'language'
}, inplace=True)
# convert the answer to just english
survey.gender = survey.gender.apply(lambda x: x[0])
survey.language = survey.language.map({'English': 'English', 'Français': 'French', '中文': 'Chinese', 'Türkçe': 'Turkish'})
survey.head()
# Out:
#                      timestamp gender  age language  \
# 0  2020/05/03 6:49:52 am GMT+8      M   23  English
# 1  2020/05/03 6:53:20 am GMT+8      M   22  English
# 2  2020/05/03 7:42:07 am GMT+8      F   23  Turkish
# 3  2020/05/03 7:47:39 am GMT+8      M   63  Turkish
# 4  2020/05/03 7:51:14 am GMT+8      F   57  Turkish
#
#    How much pain is this person feeling on a scale of 1 to 10?  \
# 0                                                1.0
# 1                                                6.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    How stressed do you feel when looking at this photo?  \
# 0                                                3.0
# 1                                                2.0
# 2                                                NaN
# 3                                                NaN
# ...

# %% [markdown]
# ## Pooling

# %%
# get the specific parts for each language
english_part = survey[survey.language == 'English'].iloc[:, np.r_[0:4, 4:59]]
french_part = survey[survey.language == 'French'].iloc[:, np.r_[0:4, 59:114]]
chinese_part = survey[survey.language == 'Chinese'].iloc[:, np.r_[0:4, 114:169]]
turkish_part = survey[survey.language == 'Turkish'].iloc[:, np.r_[0:4, 169:224]]
english_part.head()
# Out:
#                       timestamp gender  age language  \
# 0   2020/05/03 6:49:52 am GMT+8      M   23  English
# 1   2020/05/03 6:53:20 am GMT+8      M   22  English
# 9   2020/05/03 3:53:12 pm GMT+8      F   22  English
# 43  2020/05/03 7:35:55 pm GMT+8      M   28  English
# 64  2020/05/03 8:38:20 pm GMT+8      M   32  English
#
#     How much pain is this person feeling on a scale of 1 to 10?  \
# 0                                                 1.0
# 1                                                 6.0
# 9                                                 6.0
# 43                                                1.0
# 64                                                1.0
#
#     How stressed do you feel when looking at this photo?  \
# 0                                                 3.0
# 1                                                 2.0
# 9                                                 1.0
# 43                                                1.0
# ...

# %%
# create index to question dictionary for future convenience
questions = english_part.columns[4:]
i_to_q_dict = {f'q_{i}': q for i, q in enumerate(questions)}

# %%
# just a pandas dataframe version of the same thing
i_to_q = pd.DataFrame.from_dict(i_to_q_dict, orient='index')
i_to_q.head()
# Out:
#                                                      0
# q_0  How much pain is this person feeling on a scal...
# q_1  How stressed do you feel when looking at this ...
# q_2  How much pain is this person feeling on a scal...
# q_3  How stressed do you feel when looking at this ...
# q_4  How much pain is this person feeling on a scal...

# %%
# rename questions so that they can be easily concatenated
english_part.rename(columns={q: f'q_{i}' for i, q in enumerate(english_part.columns[4:])}, inplace=True)
french_part.rename(columns={q: f'q_{i}' for i, q in enumerate(french_part.columns[4:])}, inplace=True)
chinese_part.rename(columns={q: f'q_{i}' for i, q in enumerate(chinese_part.columns[4:])}, inplace=True)
turkish_part.rename(columns={q: f'q_{i}' for i, q in enumerate(turkish_part.columns[4:])}, inplace=True)
english_part.head()
# Out:
#                       timestamp gender  age language  q_0  q_1  q_2  q_3  \
# 0   2020/05/03 6:49:52 am GMT+8      M   23  English  1.0  3.0  3.0  5.0
# 1   2020/05/03 6:53:20 am GMT+8      M   22  English  6.0  2.0  7.0  4.0
# 9   2020/05/03 3:53:12 pm GMT+8      F   22  English  6.0  1.0  6.0  2.0
# 43  2020/05/03 7:35:55 pm GMT+8      M   28  English  1.0  1.0  2.0  3.0
# 64  2020/05/03 8:38:20 pm GMT+8      M   32  English  1.0  1.0  3.0  5.0
#
#      q_4  q_5  ...  q_45  q_46  q_47  q_48  q_49  q_50  q_51  q_52  q_53  q_54
# 0    5.0  9.0  ...   2.0   5.0   Yes   Yes   Yes    No   Yes    No   2.0   3.0
# 1    7.0  5.0  ...   1.0   4.0   Yes   Yes   Yes    No   Yes   Yes   2.0   3.0
# 9    7.0  3.0  ...   2.0   5.0   Yes   Yes   Yes    No   Yes    No   1.0   1.0
# 43   7.0  7.0  ...   1.0   5.0   Yes   Yes   Yes   Yes   Yes    No   2.0   3.0
# 64  10.0  7.0  ...   1.0   5.0    No    No    No    No   Yes    No   1.0   3.0
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Fix some answers

# %% [markdown]
# #### Correct scaling of COVID questions in French part

# %%
dict_map = { 0.0:1.0, 1.0:2.0, 2.0:2.0, 3.0:3.0, 4.0:3.0, 5.0:4.0 }
q_to_correct = ['q_54', 'q_53', 'q_46', 'q_45', 'q_43', 'q_42', 'q_41', 'q_40'] # list of Q to correct
french_part[q_to_correct] = french_part[q_to_correct].stack().map(dict_map).unstack()
print(np.unique(french_part[q_to_correct].values))
french_part[q_to_correct].head()
# Out:
# [1. 2. 3. 4.]
#     q_54  q_53  q_46  q_45  q_43  q_42  q_41  q_40
# 10   3.0   1.0   4.0   1.0   1.0   3.0   1.0   1.0
# 81   2.0   2.0   4.0   2.0   1.0   2.0   2.0   2.0
# 82   4.0   4.0   3.0   2.0   1.0   1.0   1.0   3.0
# 84   2.0   2.0   3.0   2.0   2.0   2.0   2.0   3.0
# 85   4.0   4.0   4.0   3.0   1.0   2.0   1.0   1.0

# %% [markdown]
# #### Convert the answer to "people you meet per week" to the format in English

# %%
french_range_map = { '0': '0', '1-2': '1-2', '3-5': '3-5', '5-10': '5-10', 'Plus de 10': '10+' }

french_part.iloc[:, 48] = french_part.iloc[:, 48].map(french_range_map)
french_part.iloc[:, 48]
# Out:
# 10       0
# 81       0
# 82     1-2
# 84     10+
# 85     1-2
#       ...
# 922    1-2
# 923    1-2
# 925      0
# 929    1-2
# 934    1-2
# Name: q_44, Length: 270, dtype: object

# %% [markdown]
# #### Convert the answer to True/False questions to the format in English

# %%
# it seems like for the turkish version of "My local government requires me ..."
# the answers are in linear scale (It's yes/no for other languages).
# I guess we can map 1 and 2 to Yes and 3 and 4 to No, but I'm not sure.
turkish_part.iloc[:, 51].hist()

# %%
french_tf_map = { 'Oui': 'Yes', 'Non': 'No' }
chinese_tf_map = { '是': 'Yes', '否': 'No' }
turkish_tf_map = { 'Evet': 'Yes', 'Hayır': 'No' }

french_part.iloc[:, 51:57] = french_part.iloc[:, 51:57].applymap(lambda x: french_tf_map[x])
chinese_part.iloc[:, 51:57] = chinese_part.iloc[:, 51:57].applymap(lambda x: chinese_tf_map[x])
turkish_part.iloc[:, 52:57] = turkish_part.iloc[:, 52:57].applymap(lambda x: turkish_tf_map[x])

turkish_special_map = { 1.0: 'Yes', 2.0: 'Yes', 3.0: 'No', 4.0: 'No' }
turkish_part.iloc[:, 51] = turkish_part.iloc[:, 51].map(turkish_special_map)

# %% [markdown]
# #### Fix incorrectly typed ages in Chinese part

# %%
# we'll have to remove this
chinese_part[chinese_part.age < 10]
# Out:
#                        timestamp gender  age language  q_0  q_1  q_2  q_3  \
# 445  2020/05/04 6:39:23 pm GMT+8      F    2  Chinese  4.0  3.0  7.0  5.0
#
#      q_4  q_5  ...  q_45  q_46  q_47  q_48  q_49  q_50  q_51  q_52  q_53  q_54
# 445  8.0  4.0  ...   2.0   4.0    No   Yes   Yes    No   Yes    No   2.0   4.0
#
# [1 rows x 59 columns]

# %%
chinese_part.drop([445], inplace=True)
chinese_part[chinese_part.age < 10]
# Out:
# Empty DataFrame
# Columns: [timestamp, gender, age, language, q_0, q_1, q_2, q_3, q_4, q_5, q_6, q_7, q_8, q_9, q_10, q_11, q_12, q_13, q_14, q_15, q_16, q_17, q_18, q_19, q_20, q_21, q_22, q_23, q_24, q_25, q_26, q_27, q_28, q_29, q_30, q_31, q_32, q_33, q_34, q_35, q_36, q_37, q_38, q_39, q_40, q_41, q_42, q_43, q_44, q_45, q_46, q_47, q_48, q_49, q_50, q_51, q_52, q_53, q_54]
# Index: []
#
# [0 rows x 59 columns]

# %%
# they typed their birth year
chinese_part[chinese_part.age > 100]
# Out:
#                        timestamp gender   age language  q_0  q_1  q_2  q_3  \
# 390  2020/05/04 4:24:54 pm GMT+8      F  1976  Chinese  4.0  3.0  7.0  7.0
# 477  2020/05/04 7:57:55 pm GMT+8      M  1963  Chinese  1.0  1.0  3.0  1.0
#
#      q_4   q_5  ...  q_45  q_46  q_47  q_48  q_49  q_50  q_51  q_52  q_53  \
# 390  9.0  10.0  ...   3.0   2.0   Yes   Yes   Yes    No   Yes    No   1.0
# 477  4.0   2.0  ...   4.0   1.0   Yes    No   Yes    No    No   Yes   1.0
#
#      q_54
# 390   2.0
# 477   1.0
#
# [2 rows x 59 columns]

# %%
chinese_part.loc[chinese_part.age > 100, 'age'] = 2020 - chinese_part[chinese_part.age > 100].age
chinese_part[chinese_part.age > 100]
# Out:
# Empty DataFrame
# Columns: [timestamp, gender, age, language, q_0, q_1, q_2, q_3, q_4, q_5, q_6, q_7, q_8, q_9, q_10, q_11, q_12, q_13, q_14, q_15, q_16, q_17, q_18, q_19, q_20, q_21, q_22, q_23, q_24, q_25, q_26, q_27, q_28, q_29, q_30, q_31, q_32, q_33, q_34, q_35, q_36, q_37, q_38, q_39, q_40, q_41, q_42, q_43, q_44, q_45, q_46, q_47, q_48, q_49, q_50, q_51, q_52, q_53, q_54]
# Index: []
#
# [0 rows x 59 columns]

# %% [markdown]
# ### Compute EQ and SQ results

# %%
def compute_eq_sq(df):
    df_copy = df.copy()
    
    # adapt scores
    map_pos = { 1.0:2.0, 2.0:1.0, 3.0:0.0, 4.0:0.0 }
    map_neg = { 1.0:0.0, 2.0:0.0, 3.0:1.0, 4.0:2.0 }
    q_pos = ['q_20', 'q_21', 'q_23', 'q_25', 'q_28', 'q_30', 'q_32', 'q_33', 'q_35', 'q_36', 'q_38', 'q_39'] # list of pos Qs
    q_neg = ['q_22', 'q_24', 'q_26', 'q_27', 'q_29', 'q_31', 'q_34', 'q_37'] # list of neg Qs
    df_copy[q_pos] = df_copy[q_pos].stack().map(map_pos).unstack()
    df_copy[q_neg] = df_copy[q_neg].stack().map(map_neg).unstack()

    # calculate EQ score
    q_EQ = ['q_20', 'q_21', 'q_22', 'q_23', 'q_24', 'q_25', 'q_26', 'q_27', 'q_28', 'q_29']
    df_copy['EQ_score_raw'] = df_copy[q_EQ].sum(axis=1)

    # calculate SQ score
    q_SQ = ['q_30', 'q_31', 'q_32', 'q_33', 'q_34', 'q_35', 'q_36', 'q_37', 'q_38', 'q_39']
    df_copy['SQ_score_raw'] = df_copy[q_SQ].sum(axis=1)
    
    # standardize scores using the method specified in the paper
    df_copy['EQ_score_std'] = (df_copy['EQ_score_raw'] - df_copy['EQ_score_raw'].mean()) / 20
    df_copy['SQ_score_std'] = (df_copy['SQ_score_raw'] - df_copy['SQ_score_raw'].mean()) / 20
    
    # difference between EQ and SQ
    df_copy['D_score'] = df_copy['EQ_score_std'] - df_copy['SQ_score_std']
    
    return df_copy

# %%
english_part = compute_eq_sq(english_part)
french_part = compute_eq_sq(french_part)
chinese_part = compute_eq_sq(chinese_part)
turkish_part = compute_eq_sq(turkish_part)

# %% [markdown]
# ### Put all fixed dataframes together

# %%
pooled = pd.concat([english_part, french_part, chinese_part, turkish_part])
pooled.reset_index(drop=True, inplace=True)
pooled.head()
# Out:
#                      timestamp gender  age language  q_0  q_1  q_2  q_3   q_4  \
# 0  2020/05/03 6:49:52 am GMT+8      M   23  English  1.0  3.0  3.0  5.0   5.0
# 1  2020/05/03 6:53:20 am GMT+8      M   22  English  6.0  2.0  7.0  4.0   7.0
# 2  2020/05/03 3:53:12 pm GMT+8      F   22  English  6.0  1.0  6.0  2.0   7.0
# 3  2020/05/03 7:35:55 pm GMT+8      M   28  English  1.0  1.0  2.0  3.0   7.0
# 4  2020/05/03 8:38:20 pm GMT+8      M   32  English  1.0  1.0  3.0  5.0  10.0
#
#    q_5  ...  q_50  q_51  q_52  q_53  q_54  EQ_score_raw  SQ_score_raw  \
# 0  9.0  ...    No   Yes    No   2.0   3.0           8.0          11.0
# 1  5.0  ...    No   Yes   Yes   2.0   3.0           7.0           4.0
# 2  3.0  ...    No   Yes    No   1.0   1.0           9.0           8.0
# 3  7.0  ...   Yes   Yes    No   2.0   3.0           6.0          10.0
# 4  7.0  ...    No   Yes    No   1.0   3.0           5.0           0.0
#
#    EQ_score_std  SQ_score_std   D_score
# ...

# %%
print(f'The shape of pooled df is: {pooled.shape}')
# Out:
# The shape of pooled df is: (934, 64)

# %%
# check if there is any error in the previous steps
pooled.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Mapping the answer to "people you meet per week" to a number

# %%
range_to_num_map = { '0': 0, '1-2': 1, '3-5': 2, '5-10': 3, '10+': 4 }

pooled.iloc[:, 48] = pooled.iloc[:, 48].map(range_to_num_map)

# %% [markdown]
# ## Some simple analysis

# %%
# number of responses
print(f'Number of total responses: {pooled.shape[0]}')
print(f'Number of English responses: {english_part.shape[0]}')
print(f'Number of French responses: {french_part.shape[0]}')
print(f'Number of Chinese responses: {chinese_part.shape[0]}')
print(f'Number of Turkish responses: {turkish_part.shape[0]}')
# Out:
# Number of total responses: 934
# Number of English responses: 143
# Number of French responses: 270
# Number of Chinese responses: 251
# Number of Turkish responses: 270

# %%
all_df = [pooled, english_part, french_part, chinese_part, turkish_part]
titles = ['All', 'English', 'French', 'Chinese', 'Turkish']

# %%
# gender
fig, axs = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Gender Distribution')
labels = ['M', 'F', 'O']

for idx, df in enumerate(all_df):
    sizes = [sum(df.gender == 'M'), sum(df.gender == 'F'), sum(df.gender == 'O')]
    axs[idx].pie(sizes, labels=labels, autopct='%1.1f%%')
    axs[idx].set_title(titles[idx])

plt.show()

# %%
# age
fig, axs = plt.subplots(3, 2, figsize=(9, 9))
fig.suptitle('Age Distribution')

axs = axs.ravel()

for idx, df in enumerate(all_df):
    axs[idx].hist(df.age)
    axs[idx].set_title(titles[idx])
    axs[idx].set_xlabel('Age')
    axs[idx].set_ylabel('# of responses')

axs[-1].axis('off')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ## Preprocess data

# %%
pooled.head()
# Out:
#                      timestamp gender  age language  q_0  q_1  q_2  q_3   q_4  \
# 0  2020/05/03 6:49:52 am GMT+8      M   23  English  1.0  3.0  3.0  5.0   5.0
# 1  2020/05/03 6:53:20 am GMT+8      M   22  English  6.0  2.0  7.0  4.0   7.0
# 2  2020/05/03 3:53:12 pm GMT+8      F   22  English  6.0  1.0  6.0  2.0   7.0
# 3  2020/05/03 7:35:55 pm GMT+8      M   28  English  1.0  1.0  2.0  3.0   7.0
# 4  2020/05/03 8:38:20 pm GMT+8      M   32  English  1.0  1.0  3.0  5.0  10.0
#
#    q_5  ...  q_50  q_51  q_52  q_53  q_54  EQ_score_raw  SQ_score_raw  \
# 0  9.0  ...    No   Yes    No   2.0   3.0           8.0          11.0
# 1  5.0  ...    No   Yes   Yes   2.0   3.0           7.0           4.0
# 2  3.0  ...    No   Yes    No   1.0   1.0           9.0           8.0
# 3  7.0  ...   Yes   Yes    No   2.0   3.0           6.0          10.0
# 4  7.0  ...    No   Yes    No   1.0   3.0           5.0           0.0
#
#    EQ_score_std  SQ_score_std   D_score
# ...

# %%
pooled.iloc[:, [6, 8, 10, 12]].sum(axis=1)
# Out:
# 0      20.0
# 1      28.0
# 2      27.0
# 3      19.0
# 4      24.0
#        ...
# 929    33.0
# 930    27.0
# 931    23.0
# 932    37.0
# 933    35.0
# Length: 934, dtype: float64

# %%
def compute_e_a(df):
    df_copy = df.copy()
    
    allo_n_pain = df_copy.q_0
    allo_pains = df_copy.iloc[:, [6, 8, 10, 12]]
    allo_score = (allo_pains.sum(axis=1) - (4 * allo_n_pain)) / 4
    
    ego_n_pain = df_copy.q_10
    ego_pains = df_copy.iloc[:, [16, 18, 20, 22]]
    ego_score = (ego_pains.sum(axis=1) - (4 * ego_n_pain)) / 4
    
    df_copy['E_score_raw'] = ego_score
    df_copy['A_score_raw'] = allo_score
    
    # standardize scores
    df_copy['E_score_std'] = (ego_score - ego_score.mean()) / ego_score.std()
    df_copy['A_score_std'] = (allo_score - allo_score.mean()) / allo_score.std()
    
    # difference between egocentric score and allocentric score
    df_copy['EA_score'] = df_copy['E_score_std'] - df_copy['A_score_std']
    
    return df_copy

# %%
# add allocentric and egocentric score columns
pre_df = compute_e_a(pooled)
# drop questions we don't need
pre_df.drop([f'q_{i}' for i in range(40)], axis='columns', inplace=True)
# rename the covid related questions column
pre_df.rename(columns=dict(zip([f'q_{i}' for i in range(40, 55)], [f'covid_{i + 1}' for i in range(15)])), inplace=True)
# reorder columns (put covid related questions at the end)
pre_df = pre_df.iloc[:, [0, 1, 2, 3] + [i for i in range(19, 29)] + [i for i in range(4, 19)]]
pre_df.head()
# Out:
#                      timestamp gender  age language  EQ_score_raw  \
# 0  2020/05/03 6:49:52 am GMT+8      M   23  English           8.0
# 1  2020/05/03 6:53:20 am GMT+8      M   22  English           7.0
# 2  2020/05/03 3:53:12 pm GMT+8      F   22  English           9.0
# 3  2020/05/03 7:35:55 pm GMT+8      M   28  English           6.0
# 4  2020/05/03 8:38:20 pm GMT+8      M   32  English           5.0
#
#    SQ_score_raw  EQ_score_std  SQ_score_std   D_score  E_score_raw  ...  \
# 0          11.0     -0.071329      0.200699 -0.272028         4.75  ...
# 1           4.0     -0.121329     -0.149301  0.027972         3.75  ...
# 2           8.0     -0.021329      0.050699 -0.072028         7.75  ...
# 3          10.0     -0.171329      0.150699 -0.322028         4.50  ...
# 4           0.0     -0.221329     -0.349301  0.127972         5.75  ...
#
#    covid_6  covid_7  covid_8  covid_9  covid_10  covid_11  covid_12  covid_13  \
# ...

# %%
# create map for covid related questions
covid_q_map = i_to_q.iloc[40:].copy()
covid_q_map.set_index(pd.Index([f'covid_{i + 1}' for i in range(15)]), inplace=True)
covid_q_map.head()
# Out:
#                                                          0
# covid_1                 The COVID-19 pandemic concerns me.
# covid_2  I feel more concerned for my family than I do ...
# covid_3  I feel more concerned for society as a whole t...
# covid_4  I respect social and physical distancing measu...
# covid_5  How many people do you meet per week other tha...

# %%
pooled['q_21']
# Out:
# 0      1.0
# 1      0.0
# 2      2.0
# 3      0.0
# 4      0.0
#       ...
# 929    0.0
# 930    1.0
# 931    1.0
# 932    1.0
# 933    0.0
# Name: q_21, Length: 934, dtype: float64

# %%
pre_df['covid_1']
# Out:
# 0      2.0
# 1      3.0
# 2      2.0
# 3      3.0
# 4      1.0
#       ...
# 929    3.0
# 930    2.0
# 931    2.0
# 932    1.0
# 933    2.0
# Name: covid_1, Length: 934, dtype: float64

# %%
base_dir = 'data_corrected'
os.makedirs(base_dir, exist_ok=True)

# save preprocessed data and map for covid related questions
pre_df.to_csv(os.path.join(base_dir, 'preprocessed.csv'))
covid_q_map.to_csv(os.path.join(base_dir, 'covid_q_map.csv'))
